# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://data.cdc.gov/api/views/r8kw-7aab/rows.csv?date=20231105&accessType=DOWNLOAD')
df
# Out:
#        Data as of  Start Date    End Date     Group       Year  Month  \
# 0      11/02/2023  12/29/2019  01/04/2020   By Week  2019/2020    NaN
# 1      11/02/2023  01/05/2020  01/11/2020   By Week       2020    NaN
# 2      11/02/2023  01/12/2020  01/18/2020   By Week       2020    NaN
# 3      11/02/2023  01/19/2020  01/25/2020   By Week       2020    NaN
# 4      11/02/2023  01/26/2020  02/01/2020   By Week       2020    NaN
# ...           ...         ...         ...       ...        ...    ...
# 13549  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13550  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13551  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13552  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13553  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
#
#        MMWR Week Week Ending Date          State  COVID-19 Deaths  \
# ...

# %%
df.shape
# Out:
# (13554, 17)

# %%
df = df.drop(columns = 'Footnote')

# %%
df
# Out:
#        Data as of  Start Date    End Date     Group       Year  Month  \
# 0      11/02/2023  12/29/2019  01/04/2020   By Week  2019/2020    NaN
# 1      11/02/2023  01/05/2020  01/11/2020   By Week       2020    NaN
# 2      11/02/2023  01/12/2020  01/18/2020   By Week       2020    NaN
# 3      11/02/2023  01/19/2020  01/25/2020   By Week       2020    NaN
# 4      11/02/2023  01/26/2020  02/01/2020   By Week       2020    NaN
# ...           ...         ...         ...       ...        ...    ...
# 13549  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13550  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13551  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13552  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13553  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
#
#        MMWR Week Week Ending Date          State  COVID-19 Deaths  \
# ...

# %%
df.drop_duplicates()
# Out:
#        Data as of  Start Date    End Date     Group       Year  Month  \
# 0      11/02/2023  12/29/2019  01/04/2020   By Week  2019/2020    NaN
# 1      11/02/2023  01/05/2020  01/11/2020   By Week       2020    NaN
# 2      11/02/2023  01/12/2020  01/18/2020   By Week       2020    NaN
# 3      11/02/2023  01/19/2020  01/25/2020   By Week       2020    NaN
# 4      11/02/2023  01/26/2020  02/01/2020   By Week       2020    NaN
# ...           ...         ...         ...       ...        ...    ...
# 13549  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13550  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13551  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13552  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13553  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
#
#        MMWR Week Week Ending Date          State  COVID-19 Deaths  \
# ...

# %%
sum_of_cols = df.sum(axis=0)
print(sum_of_cols)
# Out:
# Data as of                                  11/02/202311/02/202311/02/202311/02/202311/02/...
# Start Date                                  12/29/201901/05/202001/12/202001/19/202001/26/...
# End Date                                    01/04/202001/11/202001/18/202001/25/202002/01/...
# Group                                       By WeekBy WeekBy WeekBy WeekBy WeekBy WeekBy W...
# Month                                                                                 15606.0
# MMWR Week                                                                            277182.0
# State                                       United StatesUnited StatesUnited StatesUnited ...
# COVID-19 Deaths                                                                     9247781.0
# Total Deaths                                                                      101385386.0
# Percent of Expected Deaths                                                          1557928.0
# ...

# %%
# Calculate the sum of the specific column
sum_of_column = df['Pneumonia, Influenza, or COVID-19 Deaths'].sum()
print(sum_of_column)
# Out:
# 14338647.0

# %%
new_column_name = "Weekly Tracking"  #Replace with new column name
df = df.rename(columns={"MMWR Week": new_column_name})
df
# Out:
#        Data as of  Start Date    End Date     Group       Year  Month  \
# 0      11/02/2023  12/29/2019  01/04/2020   By Week  2019/2020    NaN
# 1      11/02/2023  01/05/2020  01/11/2020   By Week       2020    NaN
# 2      11/02/2023  01/12/2020  01/18/2020   By Week       2020    NaN
# 3      11/02/2023  01/19/2020  01/25/2020   By Week       2020    NaN
# 4      11/02/2023  01/26/2020  02/01/2020   By Week       2020    NaN
# ...           ...         ...         ...       ...        ...    ...
# 13549  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13550  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13551  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13552  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13553  11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
#
#        Weekly Tracking Week Ending Date          State  COVID-19 Deaths  \
# ...

# %%
new_column_name = "Recorded Date"  #Replace with new column name
df = df.rename(columns={"Data as of": new_column_name})
df
# Out:
#       Recorded Date  Start Date    End Date     Group       Year  Month  \
# 0        11/02/2023  12/29/2019  01/04/2020   By Week  2019/2020    NaN
# 1        11/02/2023  01/05/2020  01/11/2020   By Week       2020    NaN
# 2        11/02/2023  01/12/2020  01/18/2020   By Week       2020    NaN
# 3        11/02/2023  01/19/2020  01/25/2020   By Week       2020    NaN
# 4        11/02/2023  01/26/2020  02/01/2020   By Week       2020    NaN
# ...             ...         ...         ...       ...        ...    ...
# 13549    11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13550    11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13551    11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13552    11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
# 13553    11/02/2023  01/01/2020  10/28/2023  By Total        NaN    NaN
#
#        Weekly Tracking Week Ending Date          State  COVID-19 Deaths  \
# ...

# %%
df.dtypes
# Out:
# Recorded Date                                object
# Start Date                                   object
# End Date                                     object
# Group                                        object
# Year                                         object
# Month                                       float64
# Weekly Tracking                             float64
# Week Ending Date                             object
# State                                        object
# COVID-19 Deaths                             float64
# Total Deaths                                float64
# Percent of Expected Deaths                  float64
# Pneumonia Deaths                            float64
# Pneumonia and COVID-19 Deaths               float64
# Influenza Deaths                            float64
# Pneumonia, Influenza, or COVID-19 Deaths    float64
# dtype: object

# %%
# List of column names to convert to datetime datatype
date_columns = ['Start Date', 'End Date', 'Week Ending Date']

# Converting the specified columns to datetime
df[date_columns] = df[date_columns].apply(pd.to_datetime)

# %%
df.dtypes
# Out:
# Recorded Date                                       object
# Start Date                                  datetime64[ns]
# End Date                                    datetime64[ns]
# Group                                               object
# Year                                                object
# Month                                              float64
# Weekly Tracking                                    float64
# Week Ending Date                            datetime64[ns]
# State                                               object
# COVID-19 Deaths                                    float64
# Total Deaths                                       float64
# Percent of Expected Deaths                         float64
# Pneumonia Deaths                                   float64
# Pneumonia and COVID-19 Deaths                      float64
# Influenza Deaths                                   float64
# Pneumonia, Influenza, or COVID-19 Deaths           float64
# dtype: object

# %%
df = df.fillna({'Year': 'Not Available', 'Month': 'Not Available', 'Weekly Tracking': 'Not Available', 'Week Ending Date': 'Not Available', 'Percent of Expected Deaths': 'Unknown'})
df
# Out:
#       Recorded Date Start Date   End Date     Group           Year  \
# 0        11/02/2023 2019-12-29 2020-01-04   By Week      2019/2020
# 1        11/02/2023 2020-01-05 2020-01-11   By Week           2020
# 2        11/02/2023 2020-01-12 2020-01-18   By Week           2020
# 3        11/02/2023 2020-01-19 2020-01-25   By Week           2020
# 4        11/02/2023 2020-01-26 2020-02-01   By Week           2020
# ...             ...        ...        ...       ...            ...
# 13549    11/02/2023 2020-01-01 2023-10-28  By Total  Not Available
# 13550    11/02/2023 2020-01-01 2023-10-28  By Total  Not Available
# 13551    11/02/2023 2020-01-01 2023-10-28  By Total  Not Available
# 13552    11/02/2023 2020-01-01 2023-10-28  By Total  Not Available
# 13553    11/02/2023 2020-01-01 2023-10-28  By Total  Not Available
#
#                Month Weekly Tracking     Week Ending Date          State  \
# 0      Not Available             1.0  2020-01-04 00:00:00  United States
# ...

# %%
df = df.rename(columns={'Percent of Expected Deaths': 'Expected Deaths Percentage'})
df
# Out:
#       Recorded Date Start Date   End Date     Group           Year  \
# 0        11/02/2023 2019-12-29 2020-01-04   By Week      2019/2020
# 1        11/02/2023 2020-01-05 2020-01-11   By Week           2020
# 2        11/02/2023 2020-01-12 2020-01-18   By Week           2020
# 3        11/02/2023 2020-01-19 2020-01-25   By Week           2020
# 4        11/02/2023 2020-01-26 2020-02-01   By Week           2020
# ...             ...        ...        ...       ...            ...
# 13549    11/02/2023 2020-01-01 2023-10-28  By Total  Not Available
# 13550    11/02/2023 2020-01-01 2023-10-28  By Total  Not Available
# 13551    11/02/2023 2020-01-01 2023-10-28  By Total  Not Available
# 13552    11/02/2023 2020-01-01 2023-10-28  By Total  Not Available
# 13553    11/02/2023 2020-01-01 2023-10-28  By Total  Not Available
#
#                Month Weekly Tracking     Week Ending Date          State  \
# 0      Not Available             1.0  2020-01-04 00:00:00  United States
# ...
